# %%
import pandas as pd

# %%
df1 = pd.read_csv('pokemon_data.csv')
df2 = pd.read_excel('pokemon_data.xlsx')
df3 = pd.read_csv('pokemon_data.txt',delimiter='\t')

# %%
df1.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df1.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df1['Attack']
# Out:
# 0       49
# 1       62
# 2       82
# 3      100
# 4       52
#       ...
# 795    100
# 796    160
# 797    110
# 798    160
# 799    110
# Name: Attack, Length: 800, dtype: int64

# %%
df2[['Sp. Atk','Attack']]
# Out:
#      Sp. Atk  Attack
# 0         65      49
# 1         80      62
# 2        100      82
# 3        122     100
# 4         60      52
# ..       ...     ...
# 795      100     100
# 796      160     160
# 797      150     110
# 798      170     160
# 799      130     110
#
# [800 rows x 2 columns]

# %% [markdown]
# I can't access rows directly ... for that I will have to use iloc = integer location function

# %%
df3.iloc[1:15]
# Out:
#      #                       Name Type 1  Type 2  HP  Attack  Defense  \
# 1    2                    Ivysaur  Grass  Poison  60      62       63
# 2    3                   Venusaur  Grass  Poison  80      82       83
# 3    3      VenusaurMega Venusaur  Grass  Poison  80     100      123
# 4    4                 Charmander   Fire     NaN  39      52       43
# 5    5                 Charmeleon   Fire     NaN  58      64       58
# 6    6                  Charizard   Fire  Flying  78      84       78
# 7    6  CharizardMega Charizard X   Fire  Dragon  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying  78     104       78
# 9    7                   Squirtle  Water     NaN  44      48       65
# 10   8                  Wartortle  Water     NaN  59      63       80
# 11   9                  Blastoise  Water     NaN  79      83      100
# 12   9    BlastoiseMega Blastoise  Water     NaN  79     103      120
# ...

# %%
df1.iloc[2,3]
# Out:
# 'Poison'

# %%
df1.loc[df1['Type 2'] == 'Poison']
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 16    13                 Weedle    Bug  Poison   40      35       30       20
# 17    14                 Kakuna    Bug  Poison   45      25       50       25
# 18    15               Beedrill    Bug  Poison   65      90       40       45
# 19    15  BeedrillMega Beedrill    Bug  Poison   65     150       40       15
# 48    43                 Oddish  Grass  Poison   45      50       55       75
# 49    44                  Gloom  Grass  Poison   60      65       70       85
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# ...

# %%
df2.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %% [markdown]
# Sorting Data

# %%
df1.sort_values('Name',ascending=True)
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df1.sort_values(['#','Name'],ascending = [0,1])
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 799  721              Volcanion     Fire   Water  80     110      120
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# ..   ...                    ...      ...     ...  ..     ...      ...
# 4      4             Charmander     Fire     NaN  39      52       43
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 0      1              Bulbasaur    Grass  Poison  45      49       49
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 799      130       90     70           6       True
# ...

# %% [markdown]
# Making changes in data

# %%
df1['Total'] = df1.HP  +  df1.Attack
df1
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False     94
# ...

# %%
df1 = df1.drop(columns=['Total'])

# %%
df1
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df1['Total'] = df1.iloc[:,4:10].sum(axis=1)

# %%
df1
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %%
df1.sort_values(['Total'],ascending=True)
# Out:
#        #                   Name   Type 1    Type 2   HP  Attack  Defense  \
# 206  191                Sunkern    Grass       NaN   30      30       30
# 322  298                Azurill   Normal     Fairy   50      20       40
# 446  401              Kricketot      Bug       NaN   37      25       41
# 16    13                 Weedle      Bug    Poison   40      35       30
# 288  265                Wurmple      Bug       NaN   45      45       35
# ..   ...                    ...      ...       ...  ...     ...      ...
# 424  383  GroudonPrimal Groudon   Ground      Fire  100     180      160
# 422  382    KyogrePrimal Kyogre    Water       NaN  100     150       90
# 426  384  RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN  106     150       70
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# ...

# %%
cols = list(df1.columns)

# %%
cols
# Out:
# ['#',
#  'Name',
#  'Type 1',
#  'Type 2',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary',
#  'Total']

# %%
df1 = df1[cols[0:4]+[cols[-1]]+cols[4:-1]]

# %%
df1
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df1.to_csv('Modified.csv',index=False)

# %% [markdown]
# Filtering data : use loc function

# %%
newdf = df1.loc[(df1.Attack > 50)&(df1['Type 1'] == 'Grass')&(df1['Type 2'] == 'Poison')]

# %%
newdf
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 1      2                Ivysaur  Grass  Poison    405   60      62       63
# 2      3               Venusaur  Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 49    44                  Gloom  Grass  Poison    395   60      65       70
# 50    45              Vileplume  Grass  Poison    490   75      80       85
# 75    69             Bellsprout  Grass  Poison    300   50      75       35
# 76    70             Weepinbell  Grass  Poison    390   65      90       50
# 77    71             Victreebel  Grass  Poison    490   80     105       65
# 344  315                Roselia  Grass  Poison    400   50      60       45
# 452  407               Roserade  Grass  Poison    515   60      70       65
# 651  590                Foongus  Grass  Poison    294   69      55       45
# ...

# %%
newdf.reset_index(drop=True,inplace=True)

# %%
newdf
# Out:
#       #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0     2                Ivysaur  Grass  Poison    405   60      62       63
# 1     3               Venusaur  Grass  Poison    525   80      82       83
# 2     3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 3    44                  Gloom  Grass  Poison    395   60      65       70
# 4    45              Vileplume  Grass  Poison    490   75      80       85
# 5    69             Bellsprout  Grass  Poison    300   50      75       35
# 6    70             Weepinbell  Grass  Poison    390   65      90       50
# 7    71             Victreebel  Grass  Poison    490   80     105       65
# 8   315                Roselia  Grass  Poison    400   50      60       45
# 9   407               Roserade  Grass  Poison    515   60      70       65
# 10  590                Foongus  Grass  Poison    294   69      55       45
# ...

# %%
df1.loc[~df1['Name'].str.contains('Mega')]
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1            Bulbasaur    Grass  Poison    318   45      49       49
# 1      2              Ivysaur    Grass  Poison    405   60      62       63
# 2      3             Venusaur    Grass  Poison    525   80      82       83
# 4      4           Charmander     Fire     NaN    309   39      52       43
# 5      5           Charmeleon     Fire     NaN    405   58      64       58
# ..   ...                  ...      ...     ...    ...  ...     ...      ...
# 794  718     Zygarde50% Forme   Dragon  Ground    600  108     100      121
# 795  719              Diancie     Rock   Fairy    600   50     100      150
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 799  721            Volcanion     Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df1.loc[df1['Type 1'].str.contains('Grass|Poison',regex=True)]
# Out:
#        #                   Name  Type 1    Type 2  Total   HP  Attack  \
# 0      1              Bulbasaur   Grass    Poison    318   45      49
# 1      2                Ivysaur   Grass    Poison    405   60      62
# 2      3               Venusaur   Grass    Poison    525   80      82
# 3      3  VenusaurMega Venusaur   Grass    Poison    625   80     100
# 28    23                  Ekans  Poison       NaN    288   35      60
# ..   ...                    ...     ...       ...    ...  ...     ...
# 720  652             Chesnaught   Grass  Fighting    530   88     107
# 740  672                 Skiddo   Grass       NaN    350   66      65
# 741  673                 Gogoat   Grass       NaN    531  123     100
# 760  690                 Skrelp  Poison     Water    320   50      60
# 761  691               Dragalge  Poison    Dragon    494   65      75
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         49       65       65     45           1      False
# ...

# %%
df1.loc[df1['Type 1'] == 'Fire', 'Type 1'] = 'Flamer'

# %%
df1
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander   Flamer     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion   Flamer   Water    600  80     110      120
#
# ...

# %%
df1.loc[df1['Type 1'] == 'Grass', ['Speed','Legendary' ]] = True
df1
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander   Flamer     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion   Flamer   Water    600  80     110      120
#
# ...

# %% [markdown]
# #Statistics

# %%
df = pd.read_csv('Modified.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df.loc[df['Name'].str.contains('Shuckle|Munch|lax',regex=True)]
# Out:
#        #      Name  Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 155  143   Snorlax  Normal    NaN    540  160     110       65       65
# 230  213   Shuckle     Bug   Rock    505   20      10      230       10
# 495  446  Munchlax  Normal    NaN    390  135      85       40       40
#
#      Sp. Def  Speed  Generation  Legendary
# 155      110     30           1      False
# 230      230      5           2      False
# 495       85      5           4      False

# %%
df.groupby(['Type 1']).sum()
# Out:
#               #                                               Name  \
# Type 1
# Bug       23080  CaterpieMetapodButterfreeWeedleKakunaBeedrillB...
# Dark      14302  UmbreonMurkrowSneaselHoundourHoundoomHoundoomM...
# Dragon    15180  DratiniDragonairDragoniteAltariaAltariaMega Al...
# Electric  15994  PikachuRaichuMagnemiteMagnetonVoltorbElectrode...
# Fairy      7642  ClefairyClefableCleffaTogepiTogeticSnubbullGra...
# Fighting   9824  MankeyPrimeapeMachopMachokeMachampHitmonleeHit...
# Fire      17025  CharmanderCharmeleonCharizardCharizardMega Cha...
# Flying     2711  TornadusIncarnate FormeTornadusTherian FormeNo...
# Ghost     15568  GastlyHaunterGengarGengarMega GengarMisdreavus...
# Grass     24141  BulbasaurIvysaurVenusaurVenusaurMega VenusaurO...
# Ground    11401  SandshrewSandslashDiglettDugtrioCuboneMarowakR...
# Ice       10165  JynxArticunoSwinubPiloswineDelibirdSmoochumSno...
# Normal    31279  PidgeyPidgeottoPidgeotPidgeotMega PidgeotRatta...
# ...

# %%
cols = list(df.columns)
mdf = df[cols[2:11]]
mdf
# Out:
#       Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0      Grass  Poison    318  45      49       49       65       65     45
# 1      Grass  Poison    405  60      62       63       80       80     60
# 2      Grass  Poison    525  80      82       83      100      100     80
# 3      Grass  Poison    625  80     100      123      122      120     80
# 4       Fire     NaN    309  39      52       43       60       50     65
# ..       ...     ...    ...  ..     ...      ...      ...      ...    ...
# 795     Rock   Fairy    600  50     100      150      100      150     50
# 796     Rock   Fairy    700  50     160      110      160      110    110
# 797  Psychic   Ghost    600  80     110       60      150      130     70
# 798  Psychic    Dark    680  80     160       60      170      130     80
# 799     Fire   Water    600  80     110      120      130       90     70
#
# [800 rows x 9 columns]

# %%
mdf.groupby(['Type 1']).count()
# Out:
#                                                      Type 2  Total    HP  \
# Type 1
# Bug       FlyingPoisonPoisonPoisonPoisonGrassGrassPoison...  26146  3925
# Dark      FlyingIceFireFireFireGhostGhostFlyingIceFighti...  13818  2071
# Dragon    FlyingFlyingFairyFlyingFlyingPsychicPsychicPsy...  17617  2666
# Electric  SteelSteelFlyingDragonSteelGhostFireWaterIceFl...  19510  2631
# Fairy                                          FlyingFlying   7024  1260
# Fighting          PsychicPsychicPsychicSteelSteelDarkFlying  11244  1886
# Fire      FlyingDragonFlyingFlyingRockFlyingFightingFigh...  23820  3635
# Flying                                         DragonDragon   1940   283
# Ghost     PoisonPoisonPoisonPoisonFlyingFlyingDarkDragon...  14066  2062
# Grass     PoisonPoisonPoisonPoisonPoisonPoisonPoisonPois...  29480  4709
# Ground    RockRockFlyingDragonDragonPsychicPsychicFireRo...  14000  2361
# Ice       PsychicFlyingGroundGroundFlyingPsychicWaterWat...  10403  1728
# ...
